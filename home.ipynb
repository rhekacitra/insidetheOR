# %%
import pandas as pd
import requests

# %%
import pandas as pd

clinical_url = "https://api.vitaldb.net/cases"
track_url = "https://api.vitaldb.net/trks"
lab_url = "https://api.vitaldb.net/labs"

clinical_df = pd.read_csv(clinical_url)
track_df = pd.read_csv(track_url)
lab_df = pd.read_csv(lab_url)

clinical_df.to_csv("clinical_df")
track_df.to_csv("track_df")
lab_df.to_csv("lab_df")

# %%
clinical_df = pd.read_csv("clinical_df")
track_df = pd.read_csv("track_df")
lab_df = pd.read_csv("lab_df")

# %%
# # Merge clinical and lab data on caseid
# clinical_lab_df = pd.merge(clinical_df, lab_df, on='caseid', how='left')

# # Save to CSV (optional)
# clinical_lab_df.to_csv("clinical_lab_merged.csv", index=False)

# # Preview result
# clinical_lab_df.head()

# %%
clinical_df.columns
# Out:
# Index(['Unnamed: 0', 'caseid', 'subjectid', 'casestart', 'caseend', 'anestart',
#        'aneend', 'opstart', 'opend', 'adm', 'dis', 'icu_days', 'death_inhosp',
#        'age', 'sex', 'height', 'weight', 'bmi', 'asa', 'emop', 'department',
#        'optype', 'dx', 'opname', 'approach', 'position', 'ane_type',
#        'preop_htn', 'preop_dm', 'preop_ecg', 'preop_pft', 'preop_hb',
#        'preop_plt', 'preop_pt', 'preop_aptt', 'preop_na', 'preop_k',
#        'preop_gluc', 'preop_alb', 'preop_ast', 'preop_alt', 'preop_bun',
#        'preop_cr', 'preop_ph', 'preop_hco3', 'preop_be', 'preop_pao2',
#        'preop_paco2', 'preop_sao2', 'cormack', 'airway', 'tubesize',
#        'dltubesize', 'lmasize', 'iv1', 'iv2', 'aline1', 'aline2', 'cline1',
#        'cline2', 'intraop_ebl', 'intraop_uo', 'intraop_rbc', 'intraop_ffp',
#        'intraop_crystalloid', 'intraop_colloid', 'intraop_ppf', 'intraop_mdz',
#        'intraop_ftn', 'intraop_rocu', 'intraop_vecu', 'intraop_eph',
# ...

# %% [markdown]
# Only include specific 20 cases.

# %%
# cases = [59, 353, 163, 421, 279, 58, 183, 145, 221, 419, 425, 460, 92, 242, 384, 405, 413, 427, 96, 380] 
cases = [25, 58, 68, 92, 96, 116, 135, 137, 142, 161, 203, 229, 239, 243, 256, 266, 279, 323, 375, 384, 413, 416, 458, 460, 478]
filtered_df = clinical_df[clinical_df["caseid"].isin(cases)]
filtered_df
# Out:
#      Unnamed: 0  caseid  subjectid  casestart  caseend  anestart   aneend  \
# 24           24      25       1669          0    14832     -1118  14782.0
# 57           57      58       5141          0    14724      -231  14769.0
# 67           67      68       1615          0     8781       186   8226.0
# 91           91      92       5160          0     4720      -581   4819.0
# 95           95      96       4655          0    37979     -1195  38405.0
# 115         115     116       3965          0    12772     -1482  13158.0
# 134         134     135        805          0    12170     -1564  12116.0
# 136         136     137       4851          0     7243     -1333   7007.0
# 141         141     142       3645          0    16466      -391  15809.0
# 160         160     161       5385          0    18031       -11  18289.0
# 202         202     203       4546          0     6706      -134   6166.0
# 228         228     229       4709          0    17742     -1122  17958.0
# ...

# %%
filtered_df
# Out:
#      Unnamed: 0  caseid  subjectid  casestart  caseend  anestart   aneend  \
# 24           24      25       1669          0    14832     -1118  14782.0
# 57           57      58       5141          0    14724      -231  14769.0
# 67           67      68       1615          0     8781       186   8226.0
# 91           91      92       5160          0     4720      -581   4819.0
# 95           95      96       4655          0    37979     -1195  38405.0
# 115         115     116       3965          0    12772     -1482  13158.0
# 134         134     135        805          0    12170     -1564  12116.0
# 136         136     137       4851          0     7243     -1333   7007.0
# 141         141     142       3645          0    16466      -391  15809.0
# 160         160     161       5385          0    18031       -11  18289.0
# 202         202     203       4546          0     6706      -134   6166.0
# 228         228     229       4709          0    17742     -1122  17958.0
# ...

# %% [markdown]
# create for patient info.

# %%
columns_to_keep_patient = ['caseid', 'age', 'sex', 'bmi', 'asa', 'height', 'anestart', 'aneend', 'optype', 'opname', 'department', 'dx', 'approach', 'position', 'ane_type'
                           , 'preop_htn', 'preop_ecg', 'preop_pt', 'preop_aptt', 'preop_hb', 'preop_plt',
                            'airway', 'cormack', 'tubesize', 'lmasize',
                            'preop_pao2', 'preop_paco2', 'preop_sao2', 'preop_pft', 
                            'preop_na', 'preop_k', 'preop_gluc', 'preop_alb', 'preop_bun', 'preop_cr',
                            'adm', 'dis', 'opstart', 'opend', 'icu_days', 'death_inhosp']
filtered_df_patient = filtered_df[columns_to_keep_patient]
filtered_df_patient.to_json("patient.json", orient="records", indent=2)

# %%
lab_df
# Out:
#         Unnamed: 0  caseid      dt  name  result
# 0                0       1  594470   alb    2.90
# 1                1       1  399575   alb    3.20
# 2                2       1   12614   alb    3.40
# 3                3       1  137855   alb    3.60
# 4                4       1  399575   alt   12.00
# ...            ...     ...     ...   ...     ...
# 928443      928443    6388    3503  sao2  100.00
# 928444      928444    6388  408770   wbc    3.28
# 928445      928445    6388  -32848   wbc    6.27
# 928446      928446    6388 -249820   wbc    7.66
# 928447      928447    6388   62645   wbc   11.34
#
# [928448 rows x 5 columns]
